# %%
import rflib
import numpy as np

def f(x):
    return x ** 2 - 1

root = rflib.root_finding(f, "Bisection", braket=[-0.5, 2], plot=True, plot_interval=[-2, 2])
print(root)
# Out:
#      method : Bisection
#   converged : True
# iterracions : 46
#        root : 1.0000000000000213
#       error : 1.7763568394002505e-14
#       alarm : None
